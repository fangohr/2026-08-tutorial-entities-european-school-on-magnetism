# %% [markdown]
# # Notebooks for Entities in scientific workflows lecture
#
# Hans Fangohr, European School on Magnetism, Uppsala August 2026

# %% [markdown]
# ### Notebooks
#
# - [1-compute-speed-from-entities.ipynb](1-compute-speed-from-entities.ipynb)
#
#    Given saved entity data from the Michelson experiment, we compute derived entities $d$ and $c$.
#
# - [2-units.ipynb](2-units.ipynb)
#
#   Introduction into computing with units.
#
# - [3-entities.ipynb](3-entities.ipynb)
#
#   Introduction to creating and using an entity.
#
# - [3-entity-collection.ipynb](3-entity-collection.ipynb)
#
#   Introduction to entity collections (allows saving and reading entity data)
#
# - [4-raw-to-entitycollection.ipynb](4-raw-to-entitycollection.ipynb)
#
#   Show how to convert raw numbers in [data/michelson-1879.dat](data/michelson-1879.dat) into entity data saved in [data/michelson-1879-entities.csv](data/michelson-1879-entities.csv). This csv file is used by notebook [1-compute-speed-from-entities.ipynb](1-compute-speed-from-entities.ipynb).

# %% [markdown]
# ### More tutorials and documentation
#
# #### Working with units
#
# - very short: [mammos_units examples](https://mammos-project.github.io/mammos/examples/mammos-units/index.html)
# - all the details in the [astropy.unit documentation](https://docs.astropy.org/en/stable/units/index.html)
#
# #### Working with entities
#
# - [mammos-entity examples](https://mammos-project.github.io/mammos/examples/mammos-entity/index.html)
